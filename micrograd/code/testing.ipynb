# %%
print("hello world!. first time using interactive python notebooks!")
print("marks official day of learning nn 11/24/2025")
# Out:
# hello world!. first time using interactive python notebooks!
# marks official day of learning nn 11/24/2025

# %%
import torch
import random
import math
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.set_default_device(device)

print(device.type + " set")
print("hello world!!")
# Out:
# cpu set
# hello world!!

# %%
data = np.loadtxt('./model/graph')

plt.plot(data, marker='o', linestyle='-')
plt.ylabel("Accuracy")
plt.xlabel("Batch")
plt.legend()
plt.title("Perfomance after 100 batches")

sns.set_theme(style="darkgrid")
sns.regplot(x=np.arange(len(data)), y=data, order=6)
# sns.lineplot(data)

plt.show
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_17584\2300575178.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# <function matplotlib.pyplot.show(close=None, block=None)>
